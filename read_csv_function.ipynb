# %%
import pandas as pd

# %%
df=pd.read_csv("noc_regions.csv")
df
df.head
df.columns
df.shape
df.size
df.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
df.head(100)
# Out:
#     NOC              region                 notes
# 0   AFG         Afghanistan                   NaN
# 1   AHO             Curacao  Netherlands Antilles
# 2   ALB             Albania                   NaN
# 3   ALG             Algeria                   NaN
# 4   AND             Andorra                   NaN
# ..  ...                 ...                   ...
# 95  IRL             Ireland                   NaN
# 96  IRQ                Iraq                   NaN
# 97  ISL             Iceland                   NaN
# 98  ISR              Israel                   NaN
# 99  ISV  Virgin Islands, US        Virgin Islands
#
# [100 rows x 3 columns]

# %%
df.tail() # last 5 rows
# Out:
#      NOC    region        notes
# 225  YEM     Yemen          NaN
# 226  YMD     Yemen  South Yemen
# 227  YUG    Serbia   Yugoslavia
# 228  ZAM    Zambia          NaN
# 229  ZIM  Zimbabwe          NaN

# %%
df.tail(8)
# Out:
#      NOC    region                   notes
# 222  VNM   Vietnam                     NaN
# 223  WIF  Trinidad  West Indies Federation
# 224  YAR     Yemen             North Yemen
# 225  YEM     Yemen                     NaN
# 226  YMD     Yemen             South Yemen
# 227  YUG    Serbia              Yugoslavia
# 228  ZAM    Zambia                     NaN
# 229  ZIM  Zimbabwe                     NaN

# %%
df.describe() #description of numerical_data
# Out:
#         NOC   region                 notes
# count   230      227                    21
# unique  230      206                    21
# top     AFG  Germany  Netherlands Antilles
# freq      1        4                     1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NOC     230 non-null    object
#  1   region  227 non-null    object
#  2   notes   21 non-null     object
# dtypes: object(3)
# memory usage: 5.5+ KB

# %%
df2=pd.read_csv("Sample Data.csv")
df2
# Out:
#                                _type  \
# 0     snscrape.modules.twitter.Tweet
# 1     snscrape.modules.twitter.Tweet
# 2     snscrape.modules.twitter.Tweet
# 3     snscrape.modules.twitter.Tweet
# 4     snscrape.modules.twitter.Tweet
# ...                              ...
# 5637  snscrape.modules.twitter.Tweet
# 5638  snscrape.modules.twitter.Tweet
# 5639  snscrape.modules.twitter.Tweet
# 5640  snscrape.modules.twitter.Tweet
# 5641  snscrape.modules.twitter.Tweet
#
#                                                     url  \
# 0     https://twitter.com/theworkingboat/status/1460...
# 1     https://twitter.com/WeHoLove/status/1460523193...
# 2     https://twitter.com/bdsrated/status/1460518587...
# 3     https://twitter.com/maggietranquila/status/146...
# 4     https://twitter.com/BadalonaCC/status/14605071...
# ...                                                 ...
# 5637  https://twitter.com/BruddaZen/status/145748830...
# 5638  https://twitter.com/YarnsWool/status/145748824...
# ...

# %%
df2.head()
# Out:
#                             _type  \
# 0  snscrape.modules.twitter.Tweet
# 1  snscrape.modules.twitter.Tweet
# 2  snscrape.modules.twitter.Tweet
# 3  snscrape.modules.twitter.Tweet
# 4  snscrape.modules.twitter.Tweet
#
#                                                  url  \
# 0  https://twitter.com/theworkingboat/status/1460...
# 1  https://twitter.com/WeHoLove/status/1460523193...
# 2  https://twitter.com/bdsrated/status/1460518587...
# 3  https://twitter.com/maggietranquila/status/146...
# 4  https://twitter.com/BadalonaCC/status/14605071...
#
#                         date  \
# 0  2021-11-16 09:54:20+00:00
# 1  2021-11-16 08:20:39+00:00
# 2  2021-11-16 08:02:21+00:00
# 3  2021-11-16 07:34:44+00:00
# 4  2021-11-16 07:16:46+00:00
#
#                                              content  \
# 0  ⭐ THANK YOU ⭐\n\nOur popular #Sunday night pub...
# 1  Ahhh big stars in #gayweho #redressparty #mick...
# 2  Without God\nour week would be\nSINDAY\nMOURND...
# ...

# %%
df2.tail()
# Out:
#                                _type  \
# 5637  snscrape.modules.twitter.Tweet
# 5638  snscrape.modules.twitter.Tweet
# 5639  snscrape.modules.twitter.Tweet
# 5640  snscrape.modules.twitter.Tweet
# 5641  snscrape.modules.twitter.Tweet
#
#                                                     url  \
# 5637  https://twitter.com/BruddaZen/status/145748830...
# 5638  https://twitter.com/YarnsWool/status/145748824...
# 5639  https://twitter.com/BringonFoxFever/status/145...
# 5640  https://twitter.com/Skye3411/status/1457487967...
# 5641  https://twitter.com/mileslong4real/status/1457...
#
#                            date  \
# 5637  2021-11-07 23:21:04+00:00
# 5638  2021-11-07 23:20:51+00:00
# 5639  2021-11-07 23:20:26+00:00
# 5640  2021-11-07 23:19:44+00:00
# 5641  2021-11-07 23:18:48+00:00
#
#                                                 content  \
# 5637  I can open up space in my heart, within my bei...
# 5638  Linda caminata (8 km) por salud y placer. #ope...
# ...

# %%
df2.describe() # numerical analysis
# Out:
#                  id   replyCount  retweetCount    likeCount  quoteCount  \
# count  5.642000e+03  5642.000000   5642.000000  5642.000000  5642.00000
# mean   1.459575e+18     0.696384      1.738568    11.747962     0.10280
# std    7.428075e+14     6.079525     12.917856   130.051678     0.86003
# min    1.457488e+18     0.000000      0.000000     0.000000     0.00000
# 25%    1.459708e+18     0.000000      0.000000     0.000000     0.00000
# 50%    1.459859e+18     0.000000      0.000000     1.000000     0.00000
# 75%    1.459936e+18     0.000000      1.000000     4.000000     0.00000
# max    1.460547e+18   348.000000    638.000000  6740.000000    42.00000
#
#        conversationId  retweetedTweet  inReplyToTweetId
# count    5.642000e+03             0.0      2.690000e+02
# mean     1.459431e+18             NaN      1.459368e+18
# std      4.463239e+15             NaN      1.250051e+15
# min      1.248502e+18             NaN      1.447878e+18
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5642 entries, 0 to 5641
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _type             5642 non-null   object
#  1   url               5642 non-null   object
#  2   date              5642 non-null   object
#  3   content           5642 non-null   object
#  4   renderedContent   5642 non-null   object
#  5   id                5642 non-null   int64
#  6   user              5642 non-null   object
#  7   replyCount        5642 non-null   int64
#  8   retweetCount      5642 non-null   int64
#  9   likeCount         5642 non-null   int64
#  10  quoteCount        5642 non-null   int64
#  11  conversationId    5642 non-null   int64
#  12  lang              5642 non-null   object
#  13  source            5642 non-null   object
#  14  sourceUrl         5642 non-null   object
#  15  sourceLabel       5642 non-null   object
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df2=pd.analysis
#
# AttributeError: module 'pandas' has no attribute 'analysis'
